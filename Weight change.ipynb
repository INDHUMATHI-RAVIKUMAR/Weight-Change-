# %%
import pandas as pd
df = pd.read_csv("weight_change_dataset.csv")
df
# Out:
#     Participant ID  Age Gender  Current Weight (lbs)  BMR (Calories)  \
# 0                1   56      M                 228.4          3102.3
# 1                2   46      F                 165.4          2275.5
# 2                3   32      F                 142.8          2119.4
# 3                4   25      F                 145.5          2181.3
# 4                5   38      M                 155.5          2463.8
# ..             ...  ...    ...                   ...             ...
# 95              96   59      M                 181.9          2622.8
# 96              97   56      F                 116.5          1736.5
# 97              98   58      F                 162.7          2188.6
# 98              99   45      M                 179.8          2671.9
# 99             100   24      M                 185.2          2830.7
#
#     Daily Calories Consumed  Daily Caloric Surplus/Deficit  \
# 0                    3916.0                          813.7
# 1                    3823.0                         1547.5
# 2                    2785.4                          666.0
# 3                    2587.3                          406.0
# 4                    3312.8                          849.0
# ..                      ...                            ...
# 95                   3656.2                         1033.4
# 96                   2756.5                         1020.0
# 97                   3344.3                         1155.8
# 98                   4000.0                         1328.1
# 99                   4000.0                         1169.3
#
#     Weight Change (lbs)  Duration (weeks) Physical Activity Level  \
# 0               0.20000                 1               Sedentary
# 1               2.40000                 6             Very Active
# 2               1.40000                 7               Sedentary
# 3               0.80000                 8               Sedentary
# 4               2.00000                10          Lightly Active
# ..                  ...               ...                     ...
# 95              0.60000                 2          Lightly Active
# 96             -8.92309                12       Moderately Active
# 97              3.60000                12          Lightly Active
# 98              2.00000                 5       Moderately Active
# 99              2.70000                 9             Very Active
#
#    Sleep Quality  Stress Level  Final Weight (lbs)
# 0      Excellent             6               228.6
# 1      Excellent             6               167.8
# 2           Good             3               144.2
# 3           Fair             2               146.3
# 4           Good             1               157.5
# ..           ...           ...                 ...
# 95     Excellent             3               182.5
# 96          Good             9               107.6
# 97          Fair             7               166.3
# 98          Fair             5               181.8
# 99          Fair             7               187.9
#
# [100 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Participant ID                   0
# Age                              0
# Gender                           0
# Current Weight (lbs)             0
# BMR (Calories)                   0
# Daily Calories Consumed          0
# Daily Caloric Surplus/Deficit    0
# Weight Change (lbs)              0
# Duration (weeks)                 0
# Physical Activity Level          0
# Sleep Quality                    0
# Stress Level                     0
# Final Weight (lbs)               0
# dtype: int64

# %%
df.describe()
# Out:
#        Participant ID         Age  Current Weight (lbs)  BMR (Calories)  \
# count      100.000000  100.000000            100.000000      100.000000
# mean        50.500000   37.910000            171.533000     2518.206000
# std         29.011492   12.219454             30.333856      364.431221
# min          1.000000   18.000000            100.000000     1566.500000
# 25%         25.750000   26.750000            153.650000     2255.050000
# 50%         50.500000   38.000000            172.150000     2519.500000
# 75%         75.250000   46.250000            192.475000     2805.975000
# max        100.000000   59.000000            238.200000     3390.800000
#
#        Daily Calories Consumed  Daily Caloric Surplus/Deficit  \
# count               100.000000                     100.000000
# mean               3518.292000                    1000.091000
# std                 513.313097                     371.560827
# min                2030.900000                      82.500000
# 25%                3233.300000                     766.950000
# 50%                3636.050000                    1013.100000
# 75%                4000.000000                    1253.325000
# max                4000.000000                    1922.500000
#
#        Weight Change (lbs)  Duration (weeks)  Stress Level  Final Weight (lbs)
# count           100.000000        100.000000    100.000000          100.000000
# mean             -2.779817          6.920000      4.810000          168.750000
# std               7.443719          3.515277      2.576879           30.588004
# min             -35.678115          1.000000      1.000000           98.200000
# 25%              -5.012312          4.000000      2.750000          149.550000
# 50%               0.100000          7.000000      5.000000          169.800000
# 75%               1.850000         10.000000      7.000000          188.300000
# max               5.000000         12.000000      9.000000          232.500000

# %%
df.dtypes
# Out:
# Participant ID                     int64
# Age                                int64
# Gender                            object
# Current Weight (lbs)             float64
# BMR (Calories)                   float64
# Daily Calories Consumed          float64
# Daily Caloric Surplus/Deficit    float64
# Weight Change (lbs)              float64
# Duration (weeks)                   int64
# Physical Activity Level           object
# Sleep Quality                     object
# Stress Level                       int64
# Final Weight (lbs)               float64
# dtype: object

# %%
df["Gender"].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df["Physical Activity Level"].unique()
# Out:
# array(['Sedentary', 'Very Active', 'Lightly Active', 'Moderately Active'],
#       dtype=object)

# %%
df["Sleep Quality"].unique()
# Out:
# array(['Excellent', 'Good', 'Fair', 'Poor'], dtype=object)

# %%
df.drop(columns=['Participant ID'],inplace=True)

# %%
df.drop(columns=['Final Weight (lbs)'],inplace=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.columns

df.rename(columns={'Current Weight (lbs)':"CurrentWeight", 'BMR (Calories)':"BMR",
       'Daily Calories Consumed':"DailyCaloriesConsumed", 'Daily Caloric Surplus/Deficit':"DailyCaloriesDeficit",
       'Weight Change (lbs)':"WeightChange", 'Duration (weeks)':"Duration", 'Physical Activity Level':"ActivityLevel",
       'Sleep Quality':"SleepQuality", 'Stress Level':"StressLevel"},inplace=True)

# %%
df
# Out:
#     Age Gender  CurrentWeight     BMR  DailyCaloriesConsumed  \
# 0    56      M          228.4  3102.3                 3916.0
# 1    46      F          165.4  2275.5                 3823.0
# 2    32      F          142.8  2119.4                 2785.4
# 3    25      F          145.5  2181.3                 2587.3
# 4    38      M          155.5  2463.8                 3312.8
# ..  ...    ...            ...     ...                    ...
# 95   59      M          181.9  2622.8                 3656.2
# 96   56      F          116.5  1736.5                 2756.5
# 97   58      F          162.7  2188.6                 3344.3
# 98   45      M          179.8  2671.9                 4000.0
# 99   24      M          185.2  2830.7                 4000.0
#
#     DailyCaloriesDeficit  WeightChange  Duration      ActivityLevel  \
# 0                  813.7       0.20000         1          Sedentary
# 1                 1547.5       2.40000         6        Very Active
# 2                  666.0       1.40000         7          Sedentary
# 3                  406.0       0.80000         8          Sedentary
# 4                  849.0       2.00000        10     Lightly Active
# ..                   ...           ...       ...                ...
# 95                1033.4       0.60000         2     Lightly Active
# 96                1020.0      -8.92309        12  Moderately Active
# 97                1155.8       3.60000        12     Lightly Active
# 98                1328.1       2.00000         5  Moderately Active
# 99                1169.3       2.70000         9        Very Active
#
#    SleepQuality  StressLevel
# 0     Excellent            6
# 1     Excellent            6
# 2          Good            3
# 3          Fair            2
# 4          Good            1
# ..          ...          ...
# 95    Excellent            3
# 96         Good            9
# 97         Fair            7
# 98         Fair            5
# 99         Fair            7
#
# [100 rows x 11 columns]

# %%
sns.barplot(x='Gender',y='WeightChange',data=df,  hue = 'Gender')
plt.show()

# %%
df1 = df.groupby("Duration").agg({"WeightChange":"mean"}).reset_index().sort_values(by='WeightChange')
sns.barplot(x='Duration',y='WeightChange',data=df1.sort_values(by='WeightChange'), hue='WeightChange')
# Out:
# <Axes: xlabel='Duration', ylabel='WeightChange'>

# %%
df1 = df.groupby("ActivityLevel").agg({"WeightChange":"mean"}).reset_index().sort_values(by='WeightChange')
sns.barplot(x='ActivityLevel',y='WeightChange',data=df1.sort_values(by='WeightChange'), hue = 'ActivityLevel')
# Out:
# <Axes: xlabel='ActivityLevel', ylabel='WeightChange'>

# %%
df1 = df.groupby("StressLevel").agg({"WeightChange":"mean"}).reset_index().sort_values(by='WeightChange')
sns.barplot(x='StressLevel',y='WeightChange',data=df1.sort_values(by='WeightChange'), hue = 'StressLevel')
# Out:
# <Axes: xlabel='StressLevel', ylabel='WeightChange'>

# %%
df1 = df.groupby("SleepQuality").agg({"WeightChange":"mean"}).reset_index().sort_values(by='WeightChange')
sns.barplot(x='SleepQuality',y='WeightChange',data=df1.sort_values(by='WeightChange'), hue = 'SleepQuality')
# Out:
# <Axes: xlabel='SleepQuality', ylabel='WeightChange'>

# %%
numerical = list(df.select_dtypes(include=['float64','int64']).columns)

# %%
sns.heatmap(df[numerical].corr().abs(),annot=True)
# Out:
# <Axes: >
